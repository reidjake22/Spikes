# %% [markdown]
# MI of neurons in the network:
# We looked at the informativity of individual neurons in the network using a “specific information” metric – cite source.
#
# Number selectivity:
#
# Mask:
# Also used a series of masks selected by visual examination – see below, to look for evidence of primitive contour detectors.
