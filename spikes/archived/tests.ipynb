# %%
    # inhibitory_monitor_1 = SpikeMonitor(inh_neuron_specs.neuron_groups[1])
    # inhibitory_monitor_2 = SpikeMonitor(inh_neuron_specs.neuron_groups[2])

    #print(inhibitory_monitor_1)
    #print(inh_neuron_specs.neuron_groups[1])

    # monitor_manager.create_monitor("spike", 0, True)
    # monitor_manager.create_monitor("spike", 1, True) 
    # monitor_manager.create_monitor("spike", 2, True)
    # monitor_manager.create_monitor("spike", 3, True)
    # monitor_manager.create_monitor("spike", 4, True)
    # monitor_manager.create_monitor("spike", 1, False)
    # monitor_manager.create_monitor("spike", 2, False)
    # monitor_manager.create_monitor("spike", 3, False)
    # monitor_manager.create_monitor("spike", 4, False)

    # run_testing_epoch(network, namespace, TEST_STIMULUS_LENGTH, NUM_INPUTS)

    # # Get monitors
    # exc_1 = monitor_manager.monitors[(0, "spike", True)]
    # exc_2 = monitor_manager.monitors[(1, "spike", True)]
    # exc_3 = monitor_manager.monitors[(2, "spike", True)]
    # exc_4 = monitor_manager.monitors[(3, "spike", True)]
    # exc_5 = monitor_manager.monitors[(4, "spike", True)]
    # inh_1 = monitor_manager.monitors[(1, "spike", False)]
    # inh_2 = monitor_manager.monitors[(2, "spike", False)]
    # inh_3 = monitor_manager.monitors[(3, "spike", False)]
    # inh_4 = monitor_manager.monitors[(4, "spike", False)]
    # monitors = [exc_1, exc_2, exc_3, exc_4, exc_5, inh_1, inh_2, inh_3, inh_4]

    # ####################    ANALYZE NETWORK   ####################
    # print("Analyzing spike data...")
    # if exc_1 is None or exc_2 is None or exc_3 is None or inh_1 is None or inh_2 is None:
    #     raise ValueError("Spike monitors not properly initialized.")
    
    # def extract_spike_heatmap(spike_monitor, width, n_filters=1, is_input=False):
    #     neuron_quantity = width * width * n_filters
    #     spikes = zip(spike_monitor.t, spike_monitor.i)
    #     spike_list = [[] for _ in range(num_neurons)]
    #     for t, i in spikes:
    #         spike_list[i].append(t)
    #     spike_counts = np.array([len(spike_list[i]) for i in range(neuron_quantity)])
    #     if is_input:
    #         spike_heatmap = spike_counts.reshape(width, width, n_filters)
    #         return(spike_counts)
    #     else:
    #         spike_heatmap = spike_counts.reshape(width, width)
    #         return(spike_heatmap)
        
    # def display_spike_heatmap(spike_heatmap, file_name, is_input=False):
    #     if is_input:
    #         fig, axs = plt.subplots(2, 4, figsize=(16, 8))
    #         for filter_idx, ax in enumerate(axs.flatten()):
    #             im = ax.imshow(summed_spike_counts_e1[:, :, filter_idx], cmap='hot', aspect='auto')
    #             ax.set_title(f"Filter {filter_idx}")
    #             ax.axis('off')
    #         cbar = fig.colorbar(im, ax=axs.ravel().tolist(), fraction=0.02, pad=0.04)
    #         plt.tight_layout()
    #         plt.savefig(filename)
    #         plt.show()
    #     else:
    #         fig = plt.figure()
    #         im = plt.imshow(data, cmap='hot', aspect='auto')
    #         plt.colorbar(im)
    #         plt.savefig(filename)
    #         plt.show()

    # def extract_binned_spike_heatmap(spike_monitor, bin_size, start_time, end_time, width, n_filters=1, is_input=False):


    # # Extract spike times and neuron indices
    # spikes_e_1 = zip(exc_1.t, exc_1.i)
    # spikes_e_2 = zip(exc_2.t, exc_2.i)
    # spikes_e_3 = zip(exc_3.t, exc_3.i)
    # spikes_i_1 = zip(inh_1.t, inh_1.i)
    # spikes_i_2 = zip(inh_2.t, inh_2.i)

    # # Initialize spike storage
    # spike_list_e_1 = [[] for _ in range(131072)]
    # spike_list_e_2 = [[] for _ in range(4096)]
    # spike_list_e_3 = [[] for _ in range(4096)]
    # spike_list_i_1 = [[] for _ in range(1024)]
    # spike_list_i_2 = [[] for _ in range(1024)]

    # # Populate spike lists
    # for t, i in spikes_e_1: spike_list_e_1[i].append(t)
    # for t, i in spikes_e_2: spike_list_e_2[i].append(t)
    # for t, i in spikes_e_3: spike_list_e_3[i].append(t)
    # for t, i in spikes_i_1: spike_list_i_1[i].append(t)
    # for t, i in spikes_i_2: spike_list_i_2[i].append(t)

    # # Compute spike counts

    # spike_counts_e_1 = np.array([len(spike_list_e_1[i]) for i in range(131072)])
    # spike_counts_e_2 = np.array([len(spike_list_e_2[i]) for i in range(4096)])
    # spike_counts_e_3 = np.array([len(spike_list_e_3[i]) for i in range(4096)])
    # spike_counts_i_1 = np.array([len(spike_list_i_1[i]) for i in range(1024)])
    # spike_counts_i_2 = np.array([len(spike_list_i_2[i]) for i in range(1024)])

    # # Reshape and visualize Poisson neuron spikes
    # summed_spike_counts_e1 = spike_counts_e_1.reshape(128, 128, 8)
    # fig, axs = plt.subplots(2, 4, figsize=(16, 8))
    # for filter_idx, ax in enumerate(axs.flatten()):
    #     im = ax.imshow(summed_spike_counts_e1[:, :, filter_idx], cmap='hot', aspect='auto')
    #     ax.set_title(f"Filter {filter_idx}")
    #     ax.axis('off')

    # cbar = fig.colorbar(im, ax=axs.ravel().tolist(), fraction=0.02, pad=0.04)
    # plt.tight_layout()
    # plt.savefig("poisson_heatmap_4l.png")
    # plt.show()

    # # Heatmaps for all excitatory and inhibitory layers
    # heatmap_data = [
    #     (spike_counts_e_2.reshape(64, 64), "excitatory_heatmap_2_4l.png"),
    #     (spike_counts_e_3.reshape(64, 64), "excitatory_heatmap_3_4l.png"),
    #     (spike_counts_i_1.reshape(32, 32), "inhibitory_heatmap_1_4l.png"),
    #     (spike_counts_i_2.reshape(32, 32), "inhibitory_heatmap_2_4l.png"),
    # ]

    # for data, filename in heatmap_data:
    #     fig = plt.figure()
    #     im = plt.imshow(data, cmap='hot', aspect='auto')
    #     plt.colorbar(im)
    #     plt.savefig(filename)
    #     plt.show()

    # ####################    BINNED RESPONSES (4s-6s)   ####################
    # print("Binning spike responses from 4s-6s...")

    # try:
    #     # Initialize binning arrays
    #     binned_spike_counts_e2 = np.zeros((num_bins, 64, 64))
    #     binned_spike_counts_e3 = np.zeros((num_bins, 64, 64))
    #     binned_spike_counts_i1 = np.zeros((num_bins, 32, 32))  # 32x32 grid
    #     binned_spike_counts_i2 = np.zeros((num_bins, 32, 32))  # 32x32 grid

    #     # Function to bin spikes
    #     def bin_spikes(spike_monitor, binned_array, grid_size):
    #         for t, i in zip(spike_monitor.t, spike_monitor.i):
    #             if start_time <= t < end_time:
    #                 bin_index = int((t - start_time) / bin_size)
    #                 row = i // grid_size
    #                 col = i % grid_size
    #                 binned_array[bin_index, row, col] += 1

    #     # Bin spikes for each layer
    #     bin_spikes(exc_2, binned_spike_counts_e2, 64)
    #     bin_spikes(exc_3, binned_spike_counts_e3, 64)
    #     bin_spikes(inh_1, binned_spike_counts_i1, 32)
    #     bin_spikes(inh_2, binned_spike_counts_i2, 32)

    #     # General function for plotting heatmaps
    #     def plot_binned_heatmaps(binned_data, filename, title_prefix):
    #         fig, axs = plt.subplots(2, 4, figsize=(16, 8))
    #         for bin_idx, ax in enumerate(axs.flatten()):
    #             im = ax.imshow(binned_data[bin_idx], cmap="hot", aspect="auto")
    #             ax.set_title(f"{title_prefix} Bin_4l_ {bin_idx + 1}")
    #             ax.axis("off")

    #         plt.colorbar(im, ax=axs, fraction=0.02)
    #         plt.tight_layout()
    #         plt.savefig(filename)
    #         plt.show()

    #     # Plot binned heatmaps for excitatory and inhibitory neurons
    #     plot_binned_heatmaps(binned_spike_counts_e2, "excitatory_binned_heatmaps_2.png", "Excitatory E2")
    #     plot_binned_heatmaps(binned_spike_counts_e3, "excitatory_binned_heatmaps_3.png", "Excitatory E3")
    #     plot_binned_heatmaps(binned_spike_counts_i1, "inhibitory_binned_heatmaps_1.png", "Inhibitory I1")
    #     plot_binned_heatmaps(binned_spike_counts_i2, "inhibitory_binned_heatmaps_2.png", "Inhibitory I2")

    # except Exception as e:
    #     print(f"❌ Error during binned response processing: {e}")


    # ####################    INTERACTIVE SHELL   ####################
    # print("Entering interactive shell...")
    # code.interact(local=globals())
